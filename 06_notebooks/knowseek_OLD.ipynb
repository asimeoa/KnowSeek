# %% [markdown]
# #  KnowSeek.Ai  Control Hub — rev04_work

# %% [markdown]
# ## 1. Environment & Setup
# - **Status:** In Progress
# - **Goal:** Prepare the computer and the AI tools.

# %% [markdown]
# ### 1.1 Virtual Env Check (.venv)
# - **Status:** Planned
# - **Task:** Check if the Python environment is active and all tools are installed.

# %% [markdown]
# ### 1.2 AI Connection (Ollama)
# - **Status:** Planned
# - **Task:** Check if Ollama is running and the models (llama3 and nomic-embed-text) are ready.

# %% [markdown]
# ### 1.3 Database Setup (ChromaDB)
# - **Status:** Planned
# - **Task:** Create the local folder where the AI will save the document information.

# %% [markdown]
# ## 2. Data & Ingestion (Module 02: DocSeek)
# - **Status:** Planned
# - **Goal:** Load the technical documents and prepare them for the AI.

# %% [markdown]
# ### 2.1 File Loader
# - **Status:** Planned
# - **Task:** Get all PDF files from your local folders (GEORGE, MICKEY, ZEUS).

# %% [markdown]
# ### 2.2 Text Splitting (Chunking)
# - **Status:** Planned
# - **Task:** Cut the long PDF text into small pieces so the AI can read them easily.

# %% [markdown]
# ### 2.3 Tagging & Metadata
# - **Status:** Planned
# - **Task:** Add an ID (like #74) and a Date to every piece of text.

# %% [markdown]
# ### 2.4 Vectorization & Storage
# - **Status:** Planned
# - **Task:** Change the text into "AI numbers" (Vectors) and save them in ChromaDB.

# %% [markdown]
# ## 3. Search & Retrieval Logic
# - **Status:** Planned
# - **Goal:** Find the right information inside the database.

# %% [markdown]
# ### 3.1 Similarity Search Queries
# - **Status:** Planned
# - **Task:** Test how the system finds relevant text when you ask a technical question.

# %% [markdown]
# ### 3.2 Confidence Score Calculation (G/Y/R)
# - **Status:** Planned
# - **Task:** Calculate how "sure" the AI is about the result (Traffic light system).

# %% [markdown]
# ### 3.3 Context Window Management
# - **Status:** Planned
# - **Task:** Select the best pieces of text to give to the AI model.

# %% [markdown]
# ## 4. RAG Implementation
# - **Status:** Planned
# - **Goal:** Let the AI generate a real answer based on your documents.

# %% [markdown]
# ### 4.1 Prompt Engineering (System Prompts)
# - **Status:** Planned
# - **Task:** Tell the AI to act like a professional engineer (Expert Mode).

# %% [markdown]
# ### 4.2 LLM Answer Generation
# - **Status:** Planned
# - **Task:** Send the text pieces to llama3 and get a clean answer back.

# %% [markdown]
# ### 4.3 Source Attribution & Citations
# - **Status:** Planned
# - **Task:** Make sure the AI tells you exactly which document and page the info is from.

# %% [markdown]
# ## 6. Evaluation & MLFlow
# - **Status:** Planned
# - **Goal:** Measure the quality of the system for your presentation.

# %% [markdown]
# ### 6.1 Experiment Tracking (MLFlow)
# - **Status:** Planned
# - **Task:** Log all tests on Port 5000 to show your progress.

# %% [markdown]
# ### 6.2 Comparison: BM25 vs. Semantic Search
# - **Status:** Planned
# - **Task:** Compare "Old Search" (Keywords) vs. "New Search" (AI) for the Midterm PPT.
